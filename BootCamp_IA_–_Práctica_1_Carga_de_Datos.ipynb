# %% [markdown]
# <a href="https://colab.research.google.com/github/OptimoCX/BootCampIA/blob/main/BootCamp_IA_%E2%80%93_Pr%C3%A1ctica_1_Carga_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 BootCamp IA – Práctica 1: Carga de Datos desde Fuentes Externas
#
# ### 📅 Fecha: 03 Jul 2025
# ### 👨‍💻 Instructor:
# ### 🎯 Objetivo:
# Familiarizarse con la lectura de datos en diferentes formatos (CSV, JSON, Excel) y desde fuentes comunes en línea como:
# - Repositorios públicos (UCI, GitHub, Government Datasets)
# - APIs JSON
# - Hojas de cálculo en línea
# - Archivos Excel remotos

# %%
import pandas as pd

# --- CSV
csv_url = "https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv"
df_csv = pd.read_csv(csv_url)
print("CSV example:")
print(df_csv.head(), "\n")
# Out:
#   Student Name  Gender   Class Level Home State    Major  \
# 0    Alexandra  Female     4. Senior         CA  English
# 1       Andrew    Male   1. Freshman         SD     Math
# 2         Anna  Female   1. Freshman         NC  English
# 3        Becky  Female  2. Sophomore         SD      Art
# 4     Benjamin    Male     4. Senior         WI  English
#
#   Extracurricular Activity
# 0               Drama Club
# 1                 Lacrosse
# 2               Basketball
# 3                 Baseball
# 4               Basketball

# %% [markdown]
# # New Section

# %%
# --- JSON
json_url = "https://jsonplaceholder.typicode.com/users"
df_json = pd.read_json(json_url)
print("JSON example:")
print(df_json[['id', 'name', 'email']].head(), "\n")

# %%
# --- Excel
excel_url = "https://file-examples.com/wp-content/uploads/2017/02/file_example_XLSX_10.xlsx"
df_excel = pd.read_excel(excel_url)
print("Excel example:")
print(df_excel.head())

# %%
# !mv !mv /content/BootCampIA/README.md /content/BootCampIA
